# %%
print ("im hungry")
# Out:
# im hungry

# %%
hungry = input("enter the status")
if hungry =='yes':
    print ("eat anything")
else:
    print("eat nothing")
# Out:
# enter the status yes
# eat anything
